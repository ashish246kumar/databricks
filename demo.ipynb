# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# %sql
use catalog superstore_catalog;
use schema bronze_schema;

# %%
# %sql
-- create schema if not exists superstore_catalog.silver_schema;
-- create schema if not exists superstore_catalog.gold_schema;
-- create schema if not exists superstore_catalog.bronze_schema;

# %%
df=spark.read.format("csv")\
    .option("header","true")\
    .option("inferSchema","true")\
    .load("/Volumes/superstore_catalog/csv_storage/csv_volume/Sample - Superstore.csv")

# %%
display(df.limit(5))
